# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Create New Column

# %%
df['New_data'] = 10

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_data
# 0      0         A/5 21171   7.2500   NaN        S        10
# 1      0          PC 17599  71.2833   C85        C        10
# 2      0  STON/O2. 3101282   7.9250   NaN        S        10
# 3      0            113803  53.1000  C123        S        10
# ...

# %%
df['Age+100'] = df['Age'] + 100

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_data  Age+100
# 0      0         A/5 21171   7.2500   NaN        S        10    122.0
# 1      0          PC 17599  71.2833   C85        C        10    138.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        10    126.0
# ...

# %%
x = 3

# %%
x * x
# Out:
# 9

# %%
x ** 2
# Out:
# 9

# %%
x ** 3
# Out:
# 27

# %%
df['Square_Pclass'] = df['Pclass'] ** 2

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_data  Age+100  \
# 0      0         A/5 21171   7.2500   NaN        S        10    122.0
# 1      0          PC 17599  71.2833   C85        C        10    138.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        10    126.0
# ...

# %%
df['Square_Pclass'] = 100

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_data  Age+100  \
# 0      0         A/5 21171   7.2500   NaN        S        10    122.0
# 1      0          PC 17599  71.2833   C85        C        10    138.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        10    126.0
# ...

# %% [markdown]
# # Remove Coulumns

# %%
step 1 --> Store into one variable 
df = df.drop('Square_Pclass', axis = 1)

# %%
df.drop('Square_Pclass', axis = 1) # Not removed permanantly
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_data  Age+100  \
# 0      0         A/5 21171   7.2500   NaN        S        10    122.0
# 1      0          PC 17599  71.2833   C85        C        10    138.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        10    126.0
# ...

# %%
step 2 
Comman of inplace = True # Do changes permanantly in main dataset

# %%
df.drop('Square_Pclass', axis = 1, inplace = True) # Do changes permanantly in main dataset

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  New_data  Age+100
# 0      0  A/5 21171   7.2500   NaN        S        10    122.0
# 1      0   PC 17599  71.2833   C85        C        10    138.0

# %%
df.drop('New_data', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age+100
# 0      0  A/5 21171   7.2500   NaN        S    122.0
# 1      0   PC 17599  71.2833   C85        C    138.0

# %%
new_data = df.drop('Age+100', axis=1)

# %%
new_data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.drop('Age+100', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['PassengerId', 'Name', 'Age'], axis=1)
# Out:
#      Survived  Pclass     Sex  SibSp  Parch            Ticket     Fare Cabin  \
# 0           0       3    male      1      0         A/5 21171   7.2500   NaN
# 1           1       1  female      1      0          PC 17599  71.2833   C85
# 2           1       3  female      0      0  STON/O2. 3101282   7.9250   NaN
# 3           1       1  female      1      0            113803  53.1000  C123
# 4           0       3    male      0      0            373450   8.0500   NaN
# ..        ...     ...     ...    ...    ...               ...      ...   ...
# 886         0       2    male      0      0            211536  13.0000   NaN
# 887         1       1  female      0      0            112053  30.0000   B42
# 888         0       3  female      1      2        W./C. 6607  23.4500   NaN
# 889         1       1    male      0      0            111369  30.0000  C148
# 890         0       3    male      0      0            370376   7.7500   NaN
#
#     Embarked  Age+100
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age+100
# 0      0         A/5 21171   7.2500   NaN        S    122.0
# 1      0          PC 17599  71.2833   C85        C    138.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    126.0
# 3      0            113803  53.1000  C123        S    135.0
# ...

# %%
numerical_data = df.drop(['PassengerId', 'Name', 'Age'], axis=1)

# %%
numerical_data.head()
# Out:
#    Survived  Pclass     Sex  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    male      1      0         A/5 21171   7.2500   NaN
# 1         1       1  female      1      0          PC 17599  71.2833   C85
# 2         1       3  female      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1  female      1      0            113803  53.1000  C123
# 4         0       3    male      0      0            373450   8.0500   NaN
#
#   Embarked  Age+100
# 0        S    122.0
# 1        C    138.0
# 2        S    126.0
# 3        S    135.0
# 4        S    135.0

# %% [markdown]
# # Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+100]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Null Values Columns

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare     Age+100
# count  891.000000  891.000000  714.000000
# mean     0.381594   32.204208  129.699118
# std      0.806057   49.693429   14.526497
# min      0.000000    0.000000  100.420000
# 25%      0.000000    7.910400  120.125000
# 50%      0.000000   14.454200  128.000000
# 75%      0.000000   31.000000  138.000000
# ...

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Null values
1.Remove Null values (It is having very less numbers)
2.Filling Null values (Mean, Median, Mode)

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# df.fillna(29.69911764705882)
df.fillna(df['Age'].mean(), inplace = True)

# %%
df[df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+100]
# Index: []

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare      Cabin Embarked  Age+100
# 0      0         A/5 21171   7.2500  29.699118        S    122.0
# 1      0          PC 17599  71.2833        C85        C    138.0
# 2      0  STON/O2. 3101282   7.9250  29.699118        S    126.0
# ...

# %%
df[df['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+100]
# Index: []

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object
